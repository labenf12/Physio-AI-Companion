# %% [markdown]
# ## Figuring out how to use OpenCV
#
#
# #Learn OpenCV
# https://learnopencv.com/ai-fitness-trainer-using-mediapipe/#Test-Cases-in-the-AI-Fitness-Trainer-Application
# Source Code:
# AI-Fitness-Trainer-Using-MediaPipe-Analyzing-Squats
# May have to go to the above website to request access, but I don't think so.S
# https://github.com/spmallick/learnopencv/tree/master/AI-Fitness-Trainer-Using-MediaPipe-Analyzing-Squats

# %%
#None of these worked. Kepy for reference. Execute the next cell to install opencv

#!sudo apt-get install python3-opencv

#sudo apt-get update -qq && \
#    sudo apt-get install libgtk2.0-dev libgtk-3-dev -y --no-install-recommends

#sudo apt-get install -y --no-install-recommends \
#    libjpeg-dev libtiff5-dev libjasper-dev libpng12-dev \
#    libavcodec-dev libavformat-dev libswscale-dev libv4l-dev \
#    libxvidcore-dev libx264-dev \
#    libatlas-base-dev gfortran \
#    openexr libilmbase12 libgstreamer1.0-dev libgstreamer-plugins-base1.0-dev libqtgui4 libqt4-test

#sudo pip3 install opencv-python
#!conda install opencv
#!pip install --no-binary opencv-python opencv-python

#A note on opencv vs libopencv vs opencv-python
#---OpenCV---
#is computer vision a library written using highly optimized C/C++ code. It makes use of multiprocessing in the background. It has a collection of a large number of algorithms tested and verifiend by the developers. The best thing about this is it's FREE under the BSD license.
#---libopencv---
#is only a metapackage. These packages do not contain actual software, they simply depend on other packages to be installed. So libopencv is a metapackage which simply references one or more related packages which are loosely grouped together. It is dedicated for installing OpenCV in Ubuntu and Debian OS.
#---opencv-python---
#is the OpenCV library available as a wrapper with bindings for python. The link also shows how to install OpenCV in Ubuntu OS.
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 MB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...

# %%
#!pip install opencv-python

# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 MB 18.7 MB/s eta 0:00:00m eta 0:00:010:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for opencv-python: filename=opencv_python-4.8.1.78-cp39-cp39-linux_x86_64.whl size=29037988 sha256=5ec62041eb1711f683babee00aac038589020df964e91091e1b090cf21a39954
#   Stored in directory: /home/laben/.cache/pip/wheels/ff/da/93/f431d1f545f205c7f159365418ec7db3ed1f661adb8c94889d
# Successfully built opencv-python
# ...

# %%
import cv2
import numpy as np
print(cv.__version__)
# Out:
# 4.8.1

# %%
# Create a VideoCapture object and read from input file
# If the input is the camera, pass 0 instead of the video file name
cap = cv2.VideoCapture('./data/output_sample.mp4')
 
# Check if camera opened successfully
if (cap.isOpened()== False): 
  print("Error opening video stream or file")
 
# Read until video is completed
while(cap.isOpened()):
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
 
    # Display the resulting frame
    cv2.imshow('Frame',frame)
 
    # Press Q on keyboard to  exit
    if cv2.waitKey(25) & 0xFF == ord('q'):
      break
 
  # Break the loop
  else: 
    break

# When everything done, release the video capture object
cap.release()
 
# Closes all the frames
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x1dc5240) is not the object's thread (0x2379f10).
# Cannot move to target thread (0x1dc5240)
#
# QObject::moveToThread: Current thread (0x1dc5240) is not the object's thread (0x2379f10).
# Cannot move to target thread (0x1dc5240)
#
# QObject::moveToThread: Current thread (0x1dc5240) is not the object's thread (0x2379f10).
# Cannot move to target thread (0x1dc5240)
#
# QObject::moveToThread: Current thread (0x1dc5240) is not the object's thread (0x2379f10).
# Cannot move to target thread (0x1dc5240)
#
# QObject::moveToThread: Current thread (0x1dc5240) is not the object's thread (0x2379f10).
# Cannot move to target thread (0x1dc5240)
#
# QObject::moveToThread: Current thread (0x1dc5240) is not the object's thread (0x2379f10).
# Cannot move to target thread (0x1dc5240)
#
# QObject::moveToThread: Current thread (0x1dc5240) is not the object's thread (0x2379f10).
# Cannot move to target thread (0x1dc5240)
#
# ...
